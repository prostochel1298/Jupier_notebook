# %%
import pandas as pd
import numpy as np
import datetime 
from datetime import datetime, date

vine = pd.read_csv(r"C:\Users\Admin\Downloads\wine_base.csv")

vine2 = vine.groupby(["country","province"]).mean()
vine2.loc["US"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15208\1426555609.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   vine2 = vine.groupby(["country","province"]).mean()
#                       Unnamed: 0     points      price
# province
# America             52222.037037  86.481481  20.962963
# Arizona             45888.923077  84.897436  27.684211
# California          77702.720365  87.682731  35.506042
# Colorado            64948.600000  84.366667  22.533333
# Connecticut         93789.500000  83.500000  14.000000
# Idaho               40375.654412  85.477941  20.294118
# Iowa                73330.000000  83.500000  13.750000
# Kentucky           121860.000000  82.250000  30.750000
# Massachusetts       79304.800000  85.100000  21.900000
# Michigan            92187.200000  83.160000  22.000000
# ...

# %%
import pandas as pd
import numpy as np
import datetime 
from datetime import datetime, date

vine = pd.read_csv(r"C:\Users\Admin\Downloads\wine_base.csv")

vine.groupby("country").count()
# Out:
#                         Unnamed: 0  description  designation  points  price  \
# country
# Albania                          2            2            0       2      2
# Argentina                     5631         5631         3936    5631   5587
# Australia                     4957         4957         3347    4957   4894
# Austria                       3057         3057         2654    3057   2483
# Bosnia and Herzegovina           4            4            1       4      4
# Brazil                          25           25           18      25     25
# Bulgaria                        77           77           51      77     77
# Canada                         196          196          145     196    194
# Chile                         5816         5816         4917    5816   5766
# China                            3            3            1       3      3
# Croatia                         89           89           60      89     83
# ...
