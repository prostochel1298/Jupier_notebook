# %%
import pandas as pd
import os
from time import sleep 
from random import randint
os.mkdir("E:/Врачи") #здесь ты сам путь выберешь куда закидывать
os.mkdir("E:/Врачи/Терапевт")
os.mkdir("E:/Врачи/Офтальмолог")


def doctor():
    print("Добро пожаловать на стойку регистарции")
    #sleep(3)
    name_doctor = input("К какому доктору вы хотите записаться?(напишите 'выход' для выхода): ").lower()
    if name_doctor == "терапевт":
        terapevt()
    elif name_doctor == "офтальмолог":
        oftalmolog()
    else:
        doctor()

  
    



def smirnova_doc():
    reg = input("Вы хотите начать процедуру регистрации?'смирнова'(да,нет): ") #вот эта подпись с фамилией для проверки рандома
    fio_smirnova1=list()
    zhaloba_smirnova1=list()
    while reg != "нет":
      fio_smirnova = input("Введите вашу Фамилию Имя Отчество: ")
      fio_smirnova1.append(fio_smirnova)
      zhaloba_smirnova = input("Введите кратко вашу жалобу: ")
      zhaloba_smirnova1.append(zhaloba_smirnova)
      reg = input("Вы хотите начать процедуру регистрации?(да,нет): ")
    df_smirnova = pd.DataFrame({"Врач":"Смирнова",
                       "Имя пациента":fio_smirnova1,
                       "Жалоба":zhaloba_smirnova1})
    df_smirnova.to_csv(r'E:/Врачи/Терапевт/smirnova.csv')
    
    
      
def petrova_doc():
    reg = input("Вы хотите начать процедуру регистрации?'петрова'(да,нет): ") #вот эта подпись с фамилией для проверки рандома
    fio_petrova1=list()
    zhaloba_petrova1=list()
    while reg != "нет":
      fio_petrova = input("Введите вашу Фамилию Имя Отчество: ")
      fio_petrova1.append(fio_petrova)
      zhaloba_petrova = input("Введите кратко вашу жалобу: ")
      zhaloba_petrova1.append(zhaloba_petrova)
      reg = input("Вы хотите начать процедуру регистрации?(да,нет): ")
    df_petrova = pd.DataFrame({"Врач":"Петрова",
                       "Имя пациента":fio_petrova1,
                       "Жалоба":zhaloba_petrova1})
    df_petrova.to_csv(r'E:/Врачи/Терапевт/petrova.csv')
    
    

    
def tihonov_doc():
    reg = input("Вы хотите начать процедуру регистрации?'тихонов'(да,нет): ") #вот эта подпись с фамилией для проверки рандома
    fio_tihonov1=list()
    zhaloba_tihonov1=list()
    while reg != "нет":
      fio_tihonov = input("Введите вашу Фамилию Имя Отчество: ")
      fio_tihonov1.append(fio_tihonov)
      zhaloba_tihonov = input("Введите кратко вашу жалобу: ")
      zhaloba_tihonov1.append(zhaloba_tihonov)
      reg = input("Вы хотите начать процедуру регистрации?(да,нет): ")
    df_tihonov = pd.DataFrame({"Врач":"Тихонов",
                       "Имя пациента":fio_tihonov1,
                       "Жалоба":zhaloba_tihonov1})
    df_tihonov.to_csv(r'E:/Врачи/Офтальмолог/tihonov.csv')
    
    
      
def lebedev_doc():
    reg = input("Вы хотите начать процедуру регистрации?'лебедев'(да,нет): ")  #вот эта подпись с фамилией для проверки рандома
    fio_lebedev1=list()
    zhaloba_lebedev1=list()
    while reg != "нет":
      fio_lebedev = input("Введите вашу Фамилию Имя Отчество: ")
      fio_lebedev1.append(fio_lebedev)
      zhaloba_lebedev = input("Введите кратко вашу жалобу: ")
      zhaloba_lebedev1.append(zhaloba_lebedev)
      reg = input("Вы хотите начать процедуру регистрации?(да,нет): ")
    df_lebedev = pd.DataFrame({"Врач":"Лебедев",
                       "Имя пациента":fio_lebedev1,
                       "Жалоба":zhaloba_lebedev1})
    df_lebedev.to_csv(r'E:/Врачи/Офтальмолог/lebedev.csv')    
    
def terapevt():
    zap = input("Напишите 'да', чтобы продолжить и напишите 'нет' если хотите выйти на стойку регистрации: ") 
    while zap!="нет" :
        number = randint(0,1)
        if number == 0:
            smirnova_doc()
        elif number == 1:
            petrova_doc()
        zap = input("Напишите 'да', чтобы продолжить и напишите 'нет' если хотите выйти на стойку регистрации: ") 
    doctor()
       
        
def oftalmolog():
    zap = input("Напишите 'да', чтобы продолжить и напишите 'нет' если хотите выйти на стойку регистрации: ") 
    while zap!="нет" :
        number = randint(0,1)
        if number == 0:
            lebedev_doc()
        elif number == 1:
            tihonov_doc()
        zap = input("Напишите 'да', чтобы продолжить и напишите 'нет' если хотите выйти на стойку регистрации: ") 
    doctor()   
    
doctor()
# Out:
# Добро пожаловать на стойку регистарции
# К какому доктору вы хотите записаться?(напишите 'выход' для выхода): офтальмолог
# Напишите 'да', чтобы продолжить и напишите 'нет' если хотите выйти на стойку регистрации: да
# Вы хотите начать процедуру регистрации?'тихонов'(да,нет): да
# Введите вашу Фамилию Имя Отчество: Альбертов Василий Блаженович
# Введите кратко вашу жалобу: Болит анус
# Вы хотите начать процедуру регистрации?(да,нет): нет
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 114
#     111         zap = input("Напишите 'да', чтобы продолжить и напишите 'нет' если хотите выйти на стойку регистрации: ")
#     112     doctor()
# --> 114 doctor()
#
# Cell In[48], line 15, in doctor()
#      13     terapevt()
#      14 elif name_doctor == "офтальмолог":
# ---> 15     oftalmolog()
#      16 else:
#      17     doctor()
#
# ...
